# %% [markdown]
# 在 启动 JupyterLab 的同一个环境（conda env） 里执行：
# jupyter lab password
#
# 改完后，重启 JupyterLab 即可生效
# jupyter lab
#
# 密码在 ~/.jupyter/jupyter_server_config.json
# 或  ~/.jupyter/jupyter_server_config.py

# %% [markdown]
# 停止 notebook
# jupyter notebook stop
